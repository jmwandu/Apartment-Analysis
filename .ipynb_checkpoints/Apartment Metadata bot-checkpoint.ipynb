# %% [markdown]
# # Aggregates the metadata for apartments in an area

# %%
from selenium import webdriver
import pandas as pd
import os

# %%
apartment_links_path = os.path.relpath("./data/Seattle, WA_links.csv")
apartment_links = pd.read_csv(apartment_links_path)

# %% [markdown]
# ## Create dictionaries that will represent information groupings

# %%
vendor_info = {
    "propertyName":[],
    "verified":[],
    "street":[],
    "city":[],
    "state":[],
    "zipCode":[],
    "neighborhood": [],
    "reviewScore":[],
    "reviewCount":[],
    "walkScore":[],
    "transitScore":[]
}
 
aptType_info = {
    "propertyName":[],
    "room":[],
    "costRange": []
}

amenites_info = {
    "propertyName":[],
    "amenitytype":[],
    "amenity":[]
}

listing_info = {
    "propertyName":[],
    "beds": [],
    "baths": [],
    "rent": [],
    "sqft": [],
    "availability": [],
    "deposit": [],
    "unit": [],
    "leaseLength": [],
    "name":[],
    "new": [],
    "applyNow" : []
    
}

# %% [markdown]
# ## Get vendor Information

# %%
def getVendorInformation(vendor_info, driver):
    property_class_name = "propertyName"
    property_field = driver.find_element_by_class_name(property_class_name)
    propertyname = property_field.text
    vendor_info["propertyName"].append(propertyname)
    
    verified_class_name = "costarVerified"
    verified = False
    try:
        verified_field = driver.find_element_by_class_name(verified_class_name)
        verified_field = True
    except: 
        verified = False
    vendor_info["verified"].append(verified)
    
    
    propertyAddress_class_name = "propertyAddress"
    propertyAddress_field = driver.find_element_by_class_name(propertyAddress_class_name)
    
    address = propertyAddress_field.find_elements_by_tag_name("span")
    i = 1
    street=""
    if(address[3].text=='–'):
        street = propertyname
        i = 0
    else:
        street = address[0].text
        
    vendor_info["street"].append(street)
    
    city = address[i].text
    vendor_info["city"].append(city)
    
    state = address[i+1].text
    vendor_info["state"].append(state)
    
    zipcode = address[i+2].text
    vendor_info["zipCode"].append(zipcode)
    
    neighborhood_class_name = "neighborhoodAddress"
    neighborhood_field = driver.find_element_by_class_name(neighborhood_class_name)
    neighborhood_a_tag = neighborhood_field.find_element_by_tag_name("a")
    neighborhood = neighborhood_a_tag.text
    vendor_info['neighborhood'].append(neighborhood)
    

    reviews=0
    reviewCount=0
    
    try:
        rating_class_name = "rating"
        rating_field = driver.find_element_by_class_name(rating_class_name)
        reviews = len(rating_field.find_elements_by_class_name("starFullIcon"))
        
        reviewCountstr = rating_field.find_element_by_class_name("reviewCount").text
        reviewCountstr = reviewCountstr.replace('(',"")
        reviewCountstr = reviewCountstr.replace(')',"")
        reviewCount = int(reviewCountstr.split()[0])
        
    except:
        reviews= 0
        reviewCount= 0
        
    vendor_info["reviewScore"].append(reviews)
    vendor_info["reviewCount"].append(reviewCount)
    
    score_class_name = "score"
    score_class_fields = driver.find_elements_by_class_name(score_class_name)
    
    walkScore = score_class_fields[0].text
    vendor_info["walkScore"].append(walkScore)
    
    transitScore = score_class_fields[1].text
    vendor_info["transitScore"].append(transitScore)

# %% [markdown]
# ## Get Apartment type Information

# %%
def getAptInformation(propertyName, aptType_info, driver):
    apartmentType_class_name = "rentRollup"
    aptType_field = driver.find_elements_by_class_name(apartmentType_class_name)
    
    current = 1
    for aptType in aptType_field:
        aptType_info['propertyName'].append(propertyName)
        data = aptType.text.split('$')
        if( len(data) == 1):
            data = data[0].split(" C")
            data = "C"+data[1]
        
        costRange = data[1]
        aptType_info["costRange"].append(costRange)
        
        room = data[0]
        aptType_info['room'].append(room)

# %% [markdown]
# ## Get Amenities Information

# %%
def getAmenityInformation(propertyName, amenites_info, driver):
    section_class_name = "specGroup"
    section_field = driver.find_element_by_class_name(section_class_name)
    
    specList_class_name = "specList"
    specList = section_field.find_elements_by_class_name(specList_class_name)
    
    for spec in specList:
        amenitytype = spec.find_element_by_tag_name("h3").text
        
        try:
            p_field = spec.find_element_by_tag_name("p")
            amenites_info["amenity"].append(p.text)
            amenites_info["propertyName"].append(propertyName)
            amenites_info["amenitytype"].append(amenitytype)
        except:
            time.sleep(.001)
        try:
            ul_field = spec.find_element_by_tag_name("ul")
            li_fields = ul_field.find_elements_by_tag_name("li")
            for li in li_fields:
                amenites_info["amenity"].append(li.text)
                amenites_info["propertyName"].append(propertyName)
                amenites_info["amenitytype"].append(amenitytype)
        except:
            time.sleep(.001)
            
        try:
            h4_field = spec.find_element_by_tag_name("h4")
            amenites_info["amenity"].append(h4.text)
            amenites_info["propertyName"].append(propertyName)
            amenites_info["amenitytype"].append(amenitytype)
        except:
            time.sleep(.001)

# %% [markdown]
# ## Get listing Information

# %%
def getListingInformation(propertyName, listing_info, driver):
    table_class_name = "availabilityTable"
    table_field = driver.find_element_by_class_name(table_class_name)
    
    tablerow_class_name = "rentalGridRow"
    table_rows = table_field.find_elements_by_class_name(tablerow_class_name)
    
    for row in table_rows:
        listing_info["propertyName"].append(propertyName)
        
        bed_class_name = "beds"
        bed_field = row.find_element_by_class_name(bed_class_name)
        bed = bed_field.text
        listing_info["beds"].append(bed)
        
        bath_class_name = "baths"
        bath_field = row.find_element_by_class_name(bath_class_name)
        bath = bath_field.text
        listing_info["baths"].append(bath)
            
        rent_class_name = "rent"
        rent_field = row.find_element_by_class_name(rent_class_name)
        rent = rent_field.text
        listing_info["rent"].append(rent)
        
        deposit=""
        try:
            deposit_class_name = "deposit"
            deposit_field = row.find_element_by_class_name(deposit_class_name)
            deposit = deposit_field.text
        except:
            time.sleep(0.001)
        listing_info["deposit"].append(deposit)
        
        unit=""
        try:
            unit_class_name = "unit"
            unit_field = row.find_element_by_class_name(unit_class_name)
            unit = unit_field.text
        except:
            time.sleep(0.001)
        listing_info["unit"].append(unit)
        
        sqft_class_name = "sqft"
        sqft_field = row.find_element_by_class_name(sqft_class_name)
        sqft = sqft_field.text
        listing_info["sqft"].append(sqft)
        
        leaseLength=""
        try:
            leaseLength_class_name = "leaseLength"
            leaseLength_field = row.find_element_by_class_name(leaseLength_class_name)
            leaseLength = leaseLength_field.text
        except:
            time.sleep(.001)
        listing_info["leaseLength"].append(leaseLength)
        
        name=""
        try:
            name_class_name = "name"
            name_field = row.find_element_by_class_name(name_class_name)
            name = name_field.text
        except:
            time.sleep(.001)
        listing_info["name"].append(name)
        
        available=""
        try:
            available_class_name = "available"
            available_field = row.find_element_by_class_name(available_class_name)
            available = available_field.text
        except:
            time.sleep(.001)
        listing_info["availability"].append(available)
        
        new= ""
        try:
            new_class_name = "new"
            new_field = row.find_element_by_class_name(new_class_name)
            new = new_field.text
        except:
            time.sleep(.001)
        listing_info["new"].append(new)
        
        applyNow=""
        try:
            applyNow_class_name = "applyNow"
            applyNow_field = row.find_element_by_class_name(applyNow_class_name)
            applyNow = applyNow_field.text
        except:
            time.sleep(.001)
        listing_info["applyNow"].append(applyNow)

# %% [markdown]
# ## Create Web Driver

# %%
driverpath = os.path.relpath("./drivers/chromedriver.exe") 
driver = webdriver.Chrome(executable_path=driverpath)

# %% [markdown]
# ## load data from links

# %%
import time

i = 0
for link in apartment_links.values:
    print(link[1])
    
    driver.get(link[1])
    time.sleep(1)

    getVendorInformation(vendor_info, driver)

    propertyName = vendor_info["propertyName"][i]

    getAptInformation(propertyName, aptType_info, driver)

    getAmenityInformation(propertyName, amenites_info, driver)

    getListingInformation(propertyName, listing_info, driver)
    i+=1
# Out:
# https://www.apartments.com/luna-seattle-wa/yey9vtr/
# https://www.apartments.com/elan-41-seattle-wa/84egbw0/
# https://www.apartments.com/jackson-apartments-seattle-wa/vblnwkf/
# https://www.apartments.com/circa-green-lake-apartments-seattle-wa/bwmn6x8/
# https://www.apartments.com/tower-12-seattle-wa/sx3e5w7/
# https://www.apartments.com/common-summit-seattle-wa/1kqlte6/
# https://www.apartments.com/the-mill-at-first-hill-seattle-wa/3z5s8mg/
# https://www.apartments.com/amli-arc-seattle-wa/1yf8vx5/
# https://www.apartments.com/hana-apartments-seattle-wa/8mhszb0/
# https://www.apartments.com/the-olivian-seattle-wa/srj9ny6/
# https://www.apartments.com/amli-south-lake-union-seattle-wa/wec85fk/
# https://www.apartments.com/amli-mark24-seattle-wa/twk16f9/
# https://www.apartments.com/mckenzie-seattle-wa/tc4dx7b/
# https://www.apartments.com/cityline-seattle-wa/l4knj3g/
# https://www.apartments.com/the-kennedy-building-seattle-wa/fd6hspr/
# https://www.apartments.com/lightbox-seattle-wa/np3qvbp/
# https://www.apartments.com/sorento-flats-seattle-wa/bfnjskb/
# https://www.apartments.com/rise-on-67th-seattle-wa/ydh6cdr/
# https://www.apartments.com/olympus-seattle-wa/vyeqn7d/
# https://www.apartments.com/centennial-tower-and-court-seattle-wa/49dmkrl/
# https://www.apartments.com/cascade-seattle-wa/pwl4xcr/
# https://www.apartments.com/harbor-steps-seattle-wa/f2k13cs/
# https://www.apartments.com/saxton-seattle-wa/zsf985y/
# https://www.apartments.com/via-6-seattle-wa/kcfv0lc/
# https://www.apartments.com/helm-seattle-wa/5r5yjgm/
# https://www.apartments.com/mera-seattle-wa/mb7682j/
# https://www.apartments.com/novo-seattle-seattle-wa/nrb0ttm/
# https://www.apartments.com/maude-urban-living-seattle-wa/kx2eyyc/
# https://www.apartments.com/derby-south-lake-union-seattle-wa/xyy1rmn/
# https://www.apartments.com/griffis-belltown-seattle-wa/wp85ysj/
# https://www.apartments.com/tellus-on-dexter-apartments-seattle-wa/2t6p4k8/
# https://www.apartments.com/sitka-seattle-wa/5235n3m/
# https://www.apartments.com/ascent-south-lake-union-seattle-wa/gg967yx/
# https://www.apartments.com/marlowe-seattle-wa/7n52vsx/
# https://www.apartments.com/spruce-seattle-wa/4004bel/
# https://www.apartments.com/helios-seattle-wa/qb5scwx/
# https://www.apartments.com/park-south-seattle-wa/39gy0kf/
# https://www.apartments.com/elara-at-the-market-seattle-wa/15vbwd5/
# https://www.apartments.com/pike-motorworks-seattle-wa/36w9qlf/
# https://www.apartments.com/the-station-at-othello-park-seattle-wa/jbdwrp5/
# https://www.apartments.com/oakwood-residence-seattle-south-lake-union-seattle-wa/995kg24/
# https://www.apartments.com/chloe-on-union-seattle-wa/dqwtp9k/
# https://www.apartments.com/arthouse-seattle-wa/dgwn88h/
# https://www.apartments.com/charbern-apartments-seattle-wa/xhwycjn/
# https://www.apartments.com/leilani-apartment-homes-seattle-wa/nq961rp/
# https://www.apartments.com/assembly118-seattle-wa/bxw49bc/
# https://www.apartments.com/origin-apartments-seattle-wa/xkbt5xn/
# https://www.apartments.com/overlook-at-magnolia-seattle-wa/pmzb5pv/
# https://www.apartments.com/met-tower-seattle-wa/qjgvn6y/
# https://www.apartments.com/airmark-apartments-seattle-wa/qrmphlw/
# https://www.apartments.com/lofts-at-the-junction-seattle-wa/cpjhyce/
# https://www.apartments.com/fox-finch-apartments-seattle-wa/2vfz449/
# https://www.apartments.com/ballard-57-apartments-seattle-wa/e04s10m/
# https://www.apartments.com/odin-seattle-wa/lqkg86d/
# https://www.apartments.com/mark-on-8th-seattle-wa/j0fwr05/
# https://www.apartments.com/lane-seattle-wa/s7wg576/
# https://www.apartments.com/bogtown-flats-seattle-wa/7ttqnjy/
# https://www.apartments.com/vida-seattle-seattle-wa/97z0395/
# https://www.apartments.com/alexan-100-seattle-wa/05exse0/
# https://www.apartments.com/stazione25-seattle-wa/t6gpln8/
# https://www.apartments.com/vive-seattle-wa/2nhksx8/
# https://www.apartments.com/kiara-seattle-wa/edmmh6n/
# https://www.apartments.com/624-yale-seattle-wa/8k03zd2/
# https://www.apartments.com/westlake-steps-seattle-wa/9wpsv97/
# https://www.apartments.com/cadence-seattle-wa/ltbg8vd/
# https://www.apartments.com/infinity-apartments-seattle-wa/yszd59t/
# https://www.apartments.com/st-james-tower-seattle-wa/l0k2dve/
# https://www.apartments.com/sedona-apartments-seattle-wa/ch0j5kf/
# https://www.apartments.com/broadstone-sky-seattle-wa/nhhmrdp/
# https://www.apartments.com/overlook-at-westridge-seattle-wa/rjn5dh0/
# https://www.apartments.com/batik-seattle-wa/5kpgz8n/
# https://www.apartments.com/one-lakefront-seattle-wa/7yvbetw/
# https://www.apartments.com/juxt-seattle-wa/zm47ytw/
# https://www.apartments.com/rivet-apartments-seattle-wa/ye5ck9r/
# https://www.apartments.com/bowman-seattle-wa/3xvcwwe/
# https://www.apartments.com/malloy-seattle-wa/f7vv06v/
# https://www.apartments.com/premiere-on-pine-seattle-wa/rzcc5x1/
# https://www.apartments.com/garden-pointe-seattle-wa/n3e96pq/
# https://www.apartments.com/common-madison-seattle-wa/h8g2dd0/
# https://www.apartments.com/chroma-slu-seattle-wa/53ysvvn/
# https://www.apartments.com/kinects-tower-seattle-wa/59r318n/
# https://www.apartments.com/arrive-seattle-wa/91t6ym4/
# https://www.apartments.com/verve-apartments-seattle-wa/lywnbqg/
# https://www.apartments.com/thornton-place-seattle-wa/ftt6p0v/
# https://www.apartments.com/vertex-off-broadway-seattle-wa/c5t177e/
# https://www.apartments.com/ballard-on-the-park-seattle-wa/z754zkw/
# https://www.apartments.com/aura-west-seattle-seattle-wa/pns15wr/
# https://www.apartments.com/leeward-seattle-wa/yqyql2t/
# https://www.apartments.com/alto-apartments-seattle-wa/35y5bce/
# https://www.apartments.com/206-bell-seattle-wa/3v1hy4e/
# https://www.apartments.com/the-post-seattle-wa/ntbsfrm/
# https://www.apartments.com/summit-at-madison-park-seattle-wa/477y2vh/
# https://www.apartments.com/the-shelby-seattle-wa/cd611cd/
# https://www.apartments.com/east-howe-steps-seattle-wa/dgnwmfj/
# https://www.apartments.com/element-42-seattle-wa/qdvlfty/
# https://www.apartments.com/excelsior-seattle-wa/sd54b15/
# https://www.apartments.com/koi-seattle-wa/4pl0d7k/
# https://www.apartments.com/the-loop-seattle-wa/742mryz/
# https://www.apartments.com/the-wilcox-seattle-wa/06gzr13/
# https://www.apartments.com/3030-lake-city-seattle-wa/rpfk3p0/
# https://www.apartments.com/stack-house-seattle-wa/r9splt0/
# https://www.apartments.com/westhaven-apartments-seattle-wa/yhsgsbv/
# https://www.apartments.com/wilsonian-seattle-wa/tynqzvb/
# https://www.apartments.com/the-m-seattle-wa/d6m705l/
# https://www.apartments.com/panorama-apartments-seattle-wa/5em0kwq/
# https://www.apartments.com/slate-apartments-seattle-wa/g8rr8xz/
# https://www.apartments.com/pratt-park-apartments-seattle-wa/dflxsxk/
# https://www.apartments.com/marq-west-seattle-seattle-wa/rqnp6r1/
# https://www.apartments.com/vantage-park-apartments-seattle-wa/7xrt90z/
# https://www.apartments.com/augusta-apartments-seattle-wa/lbgnpjg/
# https://www.apartments.com/axle-seattle-wa/438lw4l/
# https://www.apartments.com/amli-wallingford-seattle-wa/sk5j017/
# https://www.apartments.com/ivy-ridge-seattle-wa/wcyj04k/
# https://www.apartments.com/moda-seattle-wa/nlqgvcm/
# https://www.apartments.com/alcyone-seattle-wa/gxmy4jw/
# https://www.apartments.com/harrison-square-seattle-wa/kgz15p9/
# https://www.apartments.com/chloe-on-madison-seattle-wa/dzd7kkl/
# https://www.apartments.com/cielo-seattle-wa/teysb79/
# https://www.apartments.com/the-leeann-seattle-wa/65vf8st/
# https://www.apartments.com/iron-flats-seattle-wa/dn77lzl/
# https://www.apartments.com/mod-apartments-seattle-wa/5nl072q/
# https://www.apartments.com/2900-on-first-seattle-wa/6bc5xqv/
# https://www.apartments.com/skye-at-belltown-seattle-wa/cvvye8f/
# https://www.apartments.com/anthem-on-12th-seattle-wa/cm38mee/
# https://www.apartments.com/marq-211-seattle-wa/66mq35t/
# https://www.apartments.com/seventh-and-james-seattle-wa/x8ckjym/
# https://www.apartments.com/springline-seattle-wa/1kmqnv5/
# https://www.apartments.com/junction-47-seattle-wa/vqxedgg/
# https://www.apartments.com/dimension-seattle-wa/01kp2y3/
# https://www.apartments.com/medora-seattle-wa/kxfyl3b/
# https://www.apartments.com/hillview-seattle-wa/v1ymrdf/
# https://www.apartments.com/east-union-seattle-wa/8sbxhc0/
# https://www.apartments.com/the-enclave-seattle-wa/d28m6wl/
# https://www.apartments.com/the-eden-apartments-seattle-wa/0ssts93/
# https://www.apartments.com/haller-post-seattle-wa/9nv2j95/
# https://www.apartments.com/washington-terrace-senior-affordable-apart-seattle-wa/1t52ye5/
# https://www.apartments.com/metro-on-first-seattle-wa/ycyc6kv/
# https://www.apartments.com/urbana-seattle-wa/hsfjf32/
# https://www.apartments.com/2300-elliott-seattle-wa/4n7xxvh/
# https://www.apartments.com/youngstown-flats-seattle-wa/7s2qyhy/
# https://www.apartments.com/coppins-well-seattle-wa/fhknn4v/
# https://www.apartments.com/john-winthrop-apartments-seattle-wa/c886jld/
# https://www.apartments.com/taylor-28-seattle-wa/z14p66x/
# https://www.apartments.com/aspira-apartments-seattle-wa/f2c4n0r/
# https://www.apartments.com/leva-on-market-seattle-wa/qqn6e1z/
# https://www.apartments.com/lighthouse-apartments-seattle-wa/x2d837m/
# https://www.apartments.com/adell-apartments-seattle-wa/d14ergl/
# https://www.apartments.com/union-bay-seattle-wa/l7flz7e/
# https://www.apartments.com/angeline-apartments-seattle-wa/66tvzer/
# https://www.apartments.com/the-heights-on-capitol-hill-seattle-wa/xpk1vsq/
# https://www.apartments.com/rianna-seattle-wa/vbs52re/
# https://www.apartments.com/three20-seattle-wa/2czbqxc/
# https://www.apartments.com/the-pearl-seattle-wa/x335j5n/
# https://www.apartments.com/square-one-seattle-wa/xlfdkdp/
# https://www.apartments.com/packard-building-seattle-wa/7xpvw4x/
# https://www.apartments.com/uwajimaya-village-seattle-wa/3f2q02f/
# https://www.apartments.com/the-blake-apartments-seattle-wa/mtjmxvl/
# https://www.apartments.com/rollin-street-seattle-wa/hjg8c83/
# https://www.apartments.com/travigne-on-11th-seattle-wa/9ncjl47/
# https://www.apartments.com/vox-seattle-wa/20ymc0c/
# https://www.apartments.com/cedar-park-senior-affordable-apartments-seattle-wa/gngssvw/
# https://www.apartments.com/prism-seattle-wa/x9v2zem/
# https://www.apartments.com/orion-seattle-wa/sjcjs87/
# https://www.apartments.com/the-perry-seattle-wa/rwd8ec0/
# https://www.apartments.com/metroline-flats-seattle-wa/lk3v29g/
# https://www.apartments.com/cypress-seattle-wa/pv15ezr/
# https://www.apartments.com/upton-flats-seattle-wa/j4k39z4/
# https://www.apartments.com/the-summit-at-lake-union-seattle-wa/l70dyjd/
# https://www.apartments.com/greenhouse-apartments-seattle-wa/2fmpmf9/
# https://www.apartments.com/the-danforth-seattle-wa/v75401g/
# https://www.apartments.com/cosmopolitan-seattle-wa/y8knpdr/
# https://www.apartments.com/epicenter-seattle-wa/j3dvz74/
# https://www.apartments.com/muse-seattle-wa/he61pb2/
# https://www.apartments.com/union-park-seattle-wa/8jpe6c0/
# https://www.apartments.com/the-martin-seattle-wa/2v0jy28/
# https://www.apartments.com/keelson-ballard-seattle-wa/10k94k7/
# https://www.apartments.com/helix-ellipse-seattle-wa/p52l3rv/
# https://www.apartments.com/the-whittaker-seattle-wa/p9bpgcr/
# https://www.apartments.com/promenade-at-the-park-seattle-wa/c67n2xe/
# https://www.apartments.com/willows-court-seattle-wa/0j92tn0/
# https://www.apartments.com/king-arthurs-court-seattle-wa/j42xet4/
# https://www.apartments.com/guinevere-seattle-wa/9zyy3f5/
# https://www.apartments.com/astro-apartments-seattle-wa/zlt3kyz/
# https://www.apartments.com/4730-california-seattle-wa/frvvjxr/
# https://www.apartments.com/brookstone-apartments-seattle-wa/5cbj7vn/
# https://www.apartments.com/verse-seattle-seattle-wa/982tvp4/
# https://www.apartments.com/true-north-seattle-wa/cmr2y9e/
# https://www.apartments.com/neptune-seattle-wa/dbk4zzk/
# https://www.apartments.com/union-slu-seattle-wa/vk13mkg/
# https://www.apartments.com/100-on-6th-seattle-wa/0fgk9q0/
# https://www.apartments.com/sonata-at-columbia-station-seattle-wa/n1nt5zm/
# https://www.apartments.com/willow-court-apartments-seattle-wa/hretqj0/
# https://www.apartments.com/andante-seattle-seattle-wa/j43dvw5/
# https://www.apartments.com/avanti-seattle-wa/s0dekb4/
# https://www.apartments.com/cyrene-seattle-wa/ykgx3qr/
# https://www.apartments.com/the-redwood-apartments-seattle-wa/dfh6vqk/
# https://www.apartments.com/gilbert-apartments-seattle-wa/n08fd0m/
# https://www.apartments.com/lucille-on-roosevelt-seattle-wa/jrtty95/
# https://www.apartments.com/holgate-12-apartments-seattle-wa/5ghwmvn/
# https://www.apartments.com/executive-estates-seattle-wa/2vnlp78/
# https://www.apartments.com/nine-pine-seattle-wa/ebf0nwn/
# https://www.apartments.com/m-street-seattle-wa/r2e3h72/
# https://www.apartments.com/maple-leaf-plaza-seattle-wa/ht15g72/
# https://www.apartments.com/avalon-micro-studios-seattle-wa/k0811y9/
# https://www.apartments.com/quintessa-apartments-seattle-wa/fwdr4rt/
# https://www.apartments.com/sheridan-beach-terrace-lake-forest-park-wa/yt6f2ms/
# https://www.apartments.com/junction-160-shoreline-wa/3neq6bf/
# https://www.apartments.com/sunset-electric-seattle-wa/n36rghn/
# https://www.apartments.com/reo-flats-seattle-wa/psbf27v/
# https://www.apartments.com/cambridge-park-villa-seattle-wa/0wnvy13/
# https://www.apartments.com/hayes-on-stone-way-seattle-wa/57zcdkm/
# https://www.apartments.com/green-lake-village-seattle-wa/dv08thk/
# https://www.apartments.com/viktoria-seattle-wa/vhsqwbf/
# https://www.apartments.com/ballard-lofts-seattle-wa/ln4hnze/
# https://www.apartments.com/campus-view-seattle-wa/nf2e3dn/
# https://www.apartments.com/dexter-seattle-wa/xmlmncq/
# https://www.apartments.com/oxford-apartments-seattle-wa/2mz83wc/
# https://www.apartments.com/zella-seattle-wa/fbcpdps/
# https://www.apartments.com/alloy-seattle-wa/9zlrch7/
# https://www.apartments.com/modera-jackson-seattle-wa/1xrgq75/
# https://www.apartments.com/array-seattle-wa/jc7yzh5/
# https://www.apartments.com/boxcar-seattle-wa/91dpdt4/
# https://www.apartments.com/modera-south-lake-union-seattle-wa/mdyqhmj/
# https://www.apartments.com/metropolitan-park-seattle-wa/xxyj11n/
# https://www.apartments.com/residences-at-3295-seattle-wa/x5l44yq/
# https://www.apartments.com/fifty-two-apartment-seattle-wa/bj6y0c9/
# https://www.apartments.com/towers-on-greenwood-seattle-wa/np8h6xq/
# https://www.apartments.com/vista-7011-seattle-wa/m1pke1l/
# https://www.apartments.com/north-court-apartments-seattle-wa/n6pemvp/
# https://www.apartments.com/monticello-seattle-wa/2bt4838/
# https://www.apartments.com/collins-on-pine-seattle-wa/se8p7y5/
# https://www.apartments.com/8th-republican-seattle-wa/8mbpsq2/
# https://www.apartments.com/expo-seattle-wa/sbrljt6/
# https://www.apartments.com/velo-and-ray-seattle-wa/h4x54t2/
# https://www.apartments.com/the-bernard-seattle-wa/869rxh3/
# https://www.apartments.com/fountain-court-seattle-wa/renq601/
# https://www.apartments.com/icon-apartments-seattle-wa/lkb3bvd/
# https://www.apartments.com/u20-apartments-seattle-wa/dgw4wwk/
# https://www.apartments.com/the-stax-seattle-wa/gekbpwy/
# https://www.apartments.com/seattle-urban-studios-seattle-wa/ch2fkgd/
# https://www.apartments.com/montisi-seattle-wa/wjlzszj/
# https://www.apartments.com/sidney-seattle-wa/wnwrg5l/
# https://www.apartments.com/the-noble-apartments-seattle-wa/j8lf2w6/
# https://www.apartments.com/amli-535-seattle-wa/v7ckjpe/
# https://www.apartments.com/marketside-flats-seattle-wa/qzz66cx/
# https://www.apartments.com/parla-seattle-wa/dh0qy5j/
# https://www.apartments.com/beryl-apt-homes-seattle-wa/q1swe6x/
# https://www.apartments.com/milan-apartments-seattle-wa/brpjwt8/
# https://www.apartments.com/ellis-court-seattle-wa/xzj65qm/
# https://www.apartments.com/mosaic-on-greenwood-seattle-wa/yhm70ds/
# https://www.apartments.com/annaliese-seattle-wa/3hg7qmd/
# https://www.apartments.com/linden-square-seattle-wa/qrfnbww/
# https://www.apartments.com/soren-apartments-seattle-wa/4gwlh0k/
# https://www.apartments.com/ava-ballard-seattle-wa/1en4zw7/
# https://www.apartments.com/canvas-seattle-wa/gs4m8my/
# https://www.apartments.com/illumina-lake-union-seattle-wa/wp5jslj/
# https://www.apartments.com/belay-apartments-seattle-wa/6j25nht/
# https://www.apartments.com/noba-apartments-seattle-wa/kngnh08/
# https://www.apartments.com/collage-seattle-wa/bk8lxkc/
# https://www.apartments.com/viva-seattle-wa/h47dk02/
# https://www.apartments.com/brentwood-square-seattle-wa/r4lwld3/
# https://www.apartments.com/domaine-seattle-wa/qebgp9w/
# https://www.apartments.com/the-audrey-at-belltown-seattle-wa/snwyk77/
# https://www.apartments.com/northgate-apartments-seattle-wa/t21ev9c/
# https://www.apartments.com/ava-queen-anne-seattle-wa/xzw3r1m/
# https://www.apartments.com/delridge-crossing-seattle-wa/ym21wdr/
# https://www.apartments.com/alley24-seattle-wa/r6k4jf2/
# https://www.apartments.com/jack-apartments-seattle-wa/zv49qhz/
# https://www.apartments.com/carolina-court-seattle-wa/pepz1js/
# https://www.apartments.com/northline-apartments-seattle-wa/d2scj5l/
# https://www.apartments.com/the-galleria-seattle-wa/qctzxyz/
# https://www.apartments.com/addison-on-fourth-seattle-wa/6tfx0gt/
# https://www.apartments.com/the-blakely-at-echo-lake-senior-55-seattle-wa/cnl684g/
# https://www.apartments.com/zindorf-seattle-wa/cmkvh2e/
# https://www.apartments.com/beacon-view-seattle-wa/nffsfmn/
# https://www.apartments.com/700-broadway-apartments-seattle-wa/09hhwk1/
# https://www.apartments.com/janus-apartments-seattle-wa/fbcqkwr/
# https://www.apartments.com/wharfside-pointe-seattle-wa/2pml6tc/
# https://www.apartments.com/o2-seattle-wa/ynmvz1v/
# https://www.apartments.com/avant-apartments-seattle-wa/ntnpjxq/
# https://www.apartments.com/sundodger-apartments-seattle-wa/wqqzmgj/
# https://www.apartments.com/thai-binh-apartments-seattle-wa/cp71zlf/
# https://www.apartments.com/pike-flats-seattle-wa/zep5k7x/
# https://www.apartments.com/1404-boylston-seattle-wa/1hz7e66/
# https://www.apartments.com/mysa-apartments-seattle-wa/vdk7fkd/
# https://www.apartments.com/avalon-belltown-towers-seattle-wa/lqg6zxd/
# https://www.apartments.com/clarendon-seattle-wa/r658lf1/
# https://www.apartments.com/ava-capitol-hill-seattle-wa/5whybzq/
# https://www.apartments.com/ava-belltown-seattle-wa/0dmpjt0/
# https://www.apartments.com/the-park-at-northgate-seattle-wa/bybgj2b/
# https://www.apartments.com/citizen-seattle-wa/vqv4lee/
# https://www.apartments.com/luxe-at-meridian-seattle-wa/9qwrlb5/
# https://www.apartments.com/joseph-arnold-lofts-seattle-wa/q2slmlw/
# https://www.apartments.com/rev-fremont-seattle-wa/p5tndjv/
# https://www.apartments.com/the-flats-at-interbay-seattle-wa/lkbxh1e/
# https://www.apartments.com/sunset-park-seattle-wa/slmnxc4/
# https://www.apartments.com/westside-flats-seattle-wa/kfy4y1c/
# https://www.apartments.com/greenlake-terrace-apartments-seattle-wa/pkt710r/
# https://www.apartments.com/rooster-apartments-seattle-wa/dm7bexl/
# https://www.apartments.com/stratus-seattle-wa/11r6ep5/
# https://www.apartments.com/oregon-42-seattle-wa/lw6g5pg/
# https://www.apartments.com/tower-801-seattle-wa/3qpwp1d/
# https://www.apartments.com/aperture-on-fifth-seattle-wa/wq94pvl/
# https://www.apartments.com/cirrus-seattle-wa/5dqy53m/
# https://www.apartments.com/the-cornelius-apartments-seattle-wa/7tb4k0x/
# https://www.apartments.com/eastlake-flats-seattle-wa/j660y34/
# https://www.apartments.com/lavie-at-queen-anne-seattle-wa/vyr43fe/
# https://www.apartments.com/manhattan-seattle-wa/5q5f6gq/
# https://www.apartments.com/walton-lofts-seattle-wa/v0lh92f/
# https://www.apartments.com/axis-seattle-wa/8j6c370/
# https://www.apartments.com/tressa-seattle-wa/g8xtqcx/
# https://www.apartments.com/park-3025-seattle-wa/pmzn0bv/
# https://www.apartments.com/city-views-seattle-wa/wg70tzh/
# https://www.apartments.com/charlesgate-seattle-wa/dkf7wml/
# https://www.apartments.com/1111-east-olive-apartments-seattle-wa/v0gk6mg/
# https://www.apartments.com/elliott-bayview-seattle-wa/q12l5sy/
# https://www.apartments.com/charbonneau-apartments-seattle-wa/n0m0h0n/
# https://www.apartments.com/999-hiawatha-apartments-seattle-wa/ymfxrvv/
# https://www.apartments.com/denny-18-seattle-wa/bqykys8/
# https://www.apartments.com/robins-nest-seattle-wa/1bl0g26/
# https://www.apartments.com/aw-larson-building-seattle-wa/b3st0eb/
# https://www.apartments.com/the-marlborough-seattle-wa/8m5h781/
# https://www.apartments.com/vibe-fremont-seattle-wa/esgt2vq/
# https://www.apartments.com/gardner-house-apartments-seattle-wa/bevnsp9/
# https://www.apartments.com/reverie-seattle-wa/dh7bsbl/
# https://www.apartments.com/noco-apartments-seattle-wa/h0k46q3/
# https://www.apartments.com/franklin-station-seattle-wa/gf18eny/
# https://www.apartments.com/autumn-ridge-apartments-seattle-wa/7wnxf2z/
# https://www.apartments.com/the-westside-seattle-wa/dp1ykdh/
# https://www.apartments.com/balfour-place-apartments-affordable-seattle-wa/hrqzpe1/
# https://www.apartments.com/skyline-house-apartments-seattle-wa/sz40d85/
# https://www.apartments.com/the-savoy-at-lake-city-seattle-wa/9xfx7r4/
# https://www.apartments.com/oslo-seattle-wa/wsgwnnj/
# https://www.apartments.com/harlow-heights-seattle-wa/1b3j314/
# https://www.apartments.com/city-watch-apartments-seattle-wa/yfs5n2s/
# https://www.apartments.com/hidden-creek-village-seattle-wa/5rp1jcq/
# https://www.apartments.com/nolan-and-nora-seattle-wa/pw4kxhs/
# https://www.apartments.com/meridian-place-apartments-seattle-wa/d8zksbk/
# https://www.apartments.com/coronado-springs-seattle-wa/yv94tct/
# https://www.apartments.com/greenwood-place-apartments-seattle-wa/xdm7kgp/
# https://www.apartments.com/northbrook-place-seattle-wa/nv65x1q/
# https://www.apartments.com/vali-hai-seattle-wa/dd3846k/
# https://www.apartments.com/aj-apartments-seattle-wa/n6erncm/
# https://www.apartments.com/sandpiper-apartments-seattle-wa/75lpwzx/
# https://www.apartments.com/la-vista-apartments-seattle-wa/332hk8g/
# https://www.apartments.com/modern-luxe-condos-seattle-wa/zkxf01x/
# https://www.apartments.com/solis-seattle-wa/k4tylg8/
# https://www.apartments.com/mcguire-court-apartments-seattle-wa/8cjj0h2/
# https://www.apartments.com/muir-apartments-seattle-wa/6c2k0ns/
# https://www.apartments.com/linden-flats-apartments-seattle-wa/elrzc1p/
# https://www.apartments.com/the-grove-seattle-wa/30mkjnf/
# https://www.apartments.com/the-nelson-seattle-wa/99x4g96/
# https://www.apartments.com/lillehammer-seattle-wa/rs62rv2/
# https://www.apartments.com/lake-washington-apartments-seattle-wa/xjkk8qm/
# https://www.apartments.com/carkeek-park-place-seattle-wa/bx1rt49/
# https://www.apartments.com/lake-city-court-seattle-wa/rgcw330/
# https://www.apartments.com/sanford-hildebrandt-seattle-active-seniors-seattle-wa/w700gmj/
# https://www.apartments.com/tod-apartments-seattle-wa/wfldyfk/
# https://www.apartments.com/rainier-vista-seattle-wa/j80th74/
# https://www.apartments.com/watercrest-lake-forest-park-wa/v0qkpyg/
# https://www.apartments.com/arbour-court-apartments-burien-wa/p90ylwv/
# https://www.apartments.com/11326-3rd-ave-ne-seattle-wa-unit-103/4kyx9lh/
# https://www.apartments.com/luna-seattle-wa/yey9vtr/
# https://www.apartments.com/verve-flats-seattle-wa/8q8cpl2/
# https://www.apartments.com/stockbridge-seattle-wa/bjk64qb/
# https://www.apartments.com/ruth-court-seattle-wa/jg1s415/
# https://www.apartments.com/kulle-urban-living-seattle-wa/2lnd318/
# https://www.apartments.com/clearwater-apartments-star-apartments-seattle-wa/m4ypnhl/
# https://www.apartments.com/elan-41-seattle-wa/84egbw0/
# https://www.apartments.com/valdok-seattle-wa/q2wzw5x/
# https://www.apartments.com/twenty20-mad-seattle-wa/gdbm6yx/
# https://www.apartments.com/northbridge-apartments-seattle-wa/06ct6m3/
# https://www.apartments.com/rainier-view-homes-seattle-wa/ll6bn7d/
# https://www.apartments.com/the-ludlow-seattle-wa/5ywg7jp/
# https://www.apartments.com/jackson-apartments-seattle-wa/vblnwkf/
# https://www.apartments.com/taylor-creek-seattle-wa/x6yp1mp/
# https://www.apartments.com/mad-flats-seattle-wa/xth2z9m/
# https://www.apartments.com/the-edge-seattle-wa/nz181vq/
# https://www.apartments.com/ori-on-the-ave-seattle-wa/dys23mh/
# https://www.apartments.com/puget-vista-seattle-wa/gk6ms4z/
# https://www.apartments.com/circa-green-lake-apartments-seattle-wa/bwmn6x8/
# https://www.apartments.com/the-weatherford-seattle-wa/nberqfn/
# https://www.apartments.com/spring-lake-apartments-seattle-wa/hx9fy92/
# https://www.apartments.com/huxley-seattle-wa/r7j56j0/
# https://www.apartments.com/southside-by-vintage-seattle-wa/5k7z6zp/
# https://www.apartments.com/the-sedges-property-seattle-wa/20p15h9/
# https://www.apartments.com/rubix-seattle-wa/d0d8fll/
# https://www.apartments.com/the-central-seattle-wa/kcbslz8/
# https://www.apartments.com/hill-crest-seattle-wa/dcw5r9j/
# https://www.apartments.com/union-arms-apartments-seattle-wa/k49mpk9/
# https://www.apartments.com/parkridge-apartments-seattle-wa/x8qnsgq/
# https://www.apartments.com/common-summit-seattle-wa/1kqlte6/
# https://www.apartments.com/magnolia-and-magnolia-crest-seattle-wa/7nlwjlw/
# https://www.apartments.com/riverview-west-apartments-seattle-wa/wy3qtxh/
# https://www.apartments.com/1715-apartments-seattle-wa/n2d0dgn/
# https://www.apartments.com/park-hill-greentree-apartments-seattle-wa/3614r9e/
# https://www.apartments.com/lake-union-tower-seattle-wa/tw3dsq8/
# https://www.apartments.com/the-mill-at-first-hill-seattle-wa/3z5s8mg/
# https://www.apartments.com/lakeview-apartments-seattle-wa/jy0e037/
# https://www.apartments.com/the-q-apartments-seattle-wa/r27w5z3/
# https://www.apartments.com/mio-apartments-seattle-wa/vwsrwjf/
# https://www.apartments.com/nova-seattle-wa/zhfzv0x/
# https://www.apartments.com/normandy-apartments-seattle-wa/b353wfb/
# https://www.apartments.com/spencer-house-seattle-wa/ylfgwlt/
# https://www.apartments.com/star-apartments-seattle-wa/xwmfdlp/
# https://www.apartments.com/blue-ridge-apartments-seattle-wa/4thgyql/
# https://www.apartments.com/the-portland-building-seattle-wa/scvcpk5/
# https://www.apartments.com/altamira-apartments-seattle-wa/xq7ntvq/
# https://www.apartments.com/hana-apartments-seattle-wa/8mhszb0/
# https://www.apartments.com/paul-revere-seattle-wa/hl8fnz1/
# https://www.apartments.com/vermont-inn-seattle-wa/7xt12dz/
# https://www.apartments.com/725c-16th-ave-seattle-wa/nt7mqeq/
# https://www.apartments.com/2100-3rd-ave-seattle-wa-unit-1401/4sgwd5l/
# https://www.apartments.com/2415-2nd-ave-seattle-wa-unit-535/p95sdsr/
# https://www.apartments.com/the-olivian-seattle-wa/srj9ny6/
# https://www.apartments.com/4505-40th-ave-sw-seattle-wa-unit-a/e9rbvfm/
# https://www.apartments.com/4410-montana-cir-seattle-wa/y3q4kss/
# https://www.apartments.com/4215-whitman-ave-n-seattle-wa-unit-104/f898bht/
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-ffb9e13e21e6> in <module>
#       8     time.sleep(1)
#       9
# ---> 10     getVendorInformation(vendor_info, driver)
#      11
#      12     propertyName = vendor_info["propertyName"][i]
#
# <ipython-input-4-6ddeaf7163cf> in getVendorInformation(vendor_info, driver)
#      68     score_class_fields = driver.find_elements_by_class_name(score_class_name)
#      69
# ---> 70     walkScore = int(score_class_fields[0].text)
#      71     vendor_info["walkScore"].append(walkScore)
#      72
#
# ValueError: invalid literal for int() with base 10: '-'

# %% [markdown]
# ## Create dataframes

# %%
print(len(amenites_info["propertyName"]))
print(len(amenites_info["amenitytype"]))
print(len(amenites_info["amenity"]))

# %%
area = "Seattle, WA"
path = "./data/"+area

vendor_info_df = pd.DataFrame.from_dict(vendor_info)
vendor_info_df.to_csv(path + "_vendor_info.csv")

# %%
aptType_info_df = pd.DataFrame.from_dict(aptType_info)
aptType_info_df.to_csv(path + "_aptType_info.csv")

# %%
amenites_info_df = pd.DataFrame.from_dict(amenites_info)
amenites_info_df.to_csv(path + "_amenites_info.csv")

# %%
listing_info_df = pd.DataFrame.from_dict(listing_info)
listing_info_df.to_csv(path + "_listing_info.csv")

# %%
driver.close()
