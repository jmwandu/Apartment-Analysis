# %%
import pandas as pd
import matplotlib  as plt

# %%
area = "Seattle, WA"
path = "./data/"+area
vendor_info_df = pd.read_csv(path + "_vendor_info.csv")
listing_info_df = pd.read_csv(path + "_listing_info.csv")
aptType_info_df = pd.read_csv(path + "_aptType_info.csv")
amenites_info_df =pd.read_csv(path + "_amenites_info.csv")

# %% [markdown]
# ## Display some basic information about rent without doing any dataframe merges yet

# %%
print("Basic rent Information")
print("The max rent in the area for : {}".format(area))
print(listing_info_df['rent'].max())
print("The min rent in the area for : {}".format(area))
print(listing_info_df[listing_info_df.rent !=0]['rent'].min())
print("The avg rent in the area for : {}".format(area))
print(listing_info_df[listing_info_df != 0][listing_info_df.sqft > 700][listing_info_df.sqft < 2000]['rent'].mean())
print()
# Out:
# Basic rent Information
# The max rent in the area for : Seattle, WA
# 15160
# The min rent in the area for : Seattle, WA
# 625
# The avg rent in the area for : Seattle, WA
# 0    1
# dtype: int64
# <ipython-input-141-619982ae5456>:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(listing_info_df[listing_info_df != 0][listing_info_df.sqft > 700][listing_info_df.sqft < 2000]['bedRoomNumber'].mode())

# %%
vendor_listing_df = pd.merge(vendor_info_df, listing_info_df, left_on="propertyName", right_on="propertyName")
vendor_listing_df[vendor_listing_df != 0][vendor_listing_df.sqft > 700][vendor_listing_df.sqft < 2000][vendor_listing_df.neighborhood =="Belltown"].groupby("bedRoomNumber").count()
# Out:
# <ipython-input-158-0678134efb37>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   vendor_listing_df[vendor_listing_df != 0][vendor_listing_df.sqft > 700][vendor_listing_df.sqft < 2000][vendor_listing_df.neighborhood =="Belltown"].groupby("bedRoomNumber").count()
#                Unnamed: 0_x  propertyName  street  city  state  zipCode  \
# bedRoomNumber
# 1                       203           203     203   203    203      203
# 2                       166           166     166   166    166      166
# 3                        12            12      12    12     12       12
#
#                neighborhood  reviewScore  reviewCount  walkScore  ...  baths  \
# bedRoomNumber                                                     ...
# 1                       203           56          147        203  ...    203
# 2                       166           44          118        166  ...    166
# ...

# %%
vendor_listing_df[vendor_listing_df != 0][vendor_listing_df.sqft > 700][vendor_listing_df.sqft < 2000][vendor_listing_df.neighborhood =="First Hill"].groupby("bedRoomNumber").count()
# Out:
# <ipython-input-148-26270f4d9c84>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   vendor_listing_df[vendor_listing_df != 0][vendor_listing_df.sqft > 700][vendor_listing_df.sqft < 2000][vendor_listing_df.neighborhood =="First Hill"].groupby("bedRoomNumber").count()
#                Unnamed: 0_x  propertyName  street  city  state  zipCode  \
# bedRoomNumber
# 1                       248           248     248   248    248      248
# 2                       284           284     284   284    284      284
# 3                         6             6       6     6      6        6
#
#                neighborhood  reviewScore  reviewCount  walkScore  ...  baths  \
# bedRoomNumber                                                     ...
# 1                       248          142          105        248  ...    248
# 2                       284          143          136        284  ...    284
# ...

# %%
amenities = pd.merge(vendor_listing_df, amenites_info_df, left_on="propertyName", right_on="propertyName")
print(amenities)
# Out:
#          Unnamed: 0_x                            propertyName  \
# 0                   0                      Jackson Apartments
# 1                   0                      Jackson Apartments
# 2                   0                      Jackson Apartments
# 3                   0                      Jackson Apartments
# 4                   0                      Jackson Apartments
# ...               ...                                     ...
# 1202637           733                         500 W Mercer St
# 1202638           735  6 br, 3 bath House - 12705 27th Ave NE
# 1202639           735  6 br, 3 bath House - 12705 27th Ave NE
# 1202640           736                      3230 SW Avalon Way
# 1202641           736                      3230 SW Avalon Way
#
#                      street     city state  zipCode      neighborhood  \
# 0         2401 S Jackson St  Seattle    WA    98144          Atlantic
# 1         2401 S Jackson St  Seattle    WA    98144          Atlantic
# ...

# %%
amenitY_groupby = amenities.groupby(["neighborhood"])["amenity"].value_counts(normalize=True)

# %%
r = listing_info_df["sqft"] / listing_info_df["rent"]

# %%
vendor_listing_df.columns
# Out:
# Index(['Unnamed: 0_x', 'propertyName', 'street', 'city', 'state', 'zipCode',
#        'neighborhood', 'reviewScore', 'reviewCount', 'walkScore',
#        'transitScore', 'Unnamed: 0_y', 'bedRoomType', 'bedRoomNumber', 'baths',
#        'rent', 'sqft', 'availability', 'deposit', 'unit', 'leaseLength',
#        'name', 'new', 'applyNow'],
#       dtype='object')

# %%
vendor_listing_df[vendor_listing_df != 0][vendor_listing_df.sqft > 700][vendor_listing_df.sqft < 2000][vendor_listing_df.neighborhood =="Capitol Hill"].groupby("bedRoomNumber").count()
# Out:
# <ipython-input-149-b5a99f3fd23e>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   vendor_listing_df[vendor_listing_df != 0][vendor_listing_df.sqft > 700][vendor_listing_df.sqft < 2000][vendor_listing_df.neighborhood =="Capitol Hill"].groupby("bedRoomNumber").count()
#                Unnamed: 0_x  propertyName  street  city  state  zipCode  \
# bedRoomNumber
# 1                       181           181     181   181    181      181
# 2                       117           117     117   117    117      117
# 3                         6             6       6     6      6        6
#
#                neighborhood  reviewScore  reviewCount  walkScore  ...  baths  \
# bedRoomNumber                                                     ...
# 1                       181           94           86        181  ...    181
# 2                       117           66           47        117  ...    117
# ...

# %%
print("The row associated with the max value display above")
print(listing_info_df[listing_info_df.rent == listing_info_df.rent.max()])
# Out:
# The row associated with the max value display above
#        Unnamed: 0 propertyName  bedRoomType  bedRoomNumber  baths   rent  \
# 2452         2452     McKenzie  Traditional              3    3.0  15160
# 10064       10064     McKenzie  Traditional              3    3.0  15160
#
#          sqft  availability  deposit unit  leaseLength         name  new  \
# 2452   2584.0             0        0  NaN            0  Penthouse C  NaN
# 10064  2584.0             0        0  NaN            0  Penthouse C  NaN
#
#       applyNow
# 2452       NaN
# 10064      NaN

# %%
print("The row associated with the MIN value display above")
print(listing_info_df[listing_info_df.rent == listing_info_df.rent.min()])
# Out:
# The row associated with the MIN value display above
#        Unnamed: 0                 propertyName  bedRoomType  bedRoomNumber  \
# 106           106                      Elan 41  Traditional              2
# 107           107                      Elan 41  Traditional              2
# 108           108                      Elan 41  Traditional              2
# 142           142  Circa Green Lake Apartments  Traditional              2
# 195           195                     Tower 12       Studio              1
# ...           ...                          ...          ...            ...
# 10629       10629                        Batik  Traditional              2
# 10630       10630                        Batik  Traditional              2
# 10631       10631                        Batik  Traditional              2
# 10640       10640                       Malloy       Studio              1
# 10641       10641                       Malloy       Studio              1
#
# ...

# %% [markdown]
# ## Display some basic information about sqft without doing any dataframe merges

# %%
print("Basic sqft Information")
print("The max sqft in the area for : {}".format(area))
print(listing_info_df['sqft'].max())
print("The min sqft in the area for : {}".format(area))
print(listing_info_df[listing_info_df.sqft !=0]['sqft'].min())
print("The avg sqft in the area for : {}".format(area))
print(listing_info_df[listing_info_df.sqft > 700][listing_info_df.sqft < 2000]['sqft'].mean())
print()
# Out:
# Basic sqft Information
# The max sqft in the area for : Seattle, WA
# 4380.0
# The min sqft in the area for : Seattle, WA
# 90.0
# The avg sqft in the area for : Seattle, WA
# 949.7142718068536
# <ipython-input-131-4a267bdaeab3>:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(listing_info_df[listing_info_df.sqft > 700][listing_info_df.sqft < 2000]['sqft'].mean())

# %%
listing_info_df[listing_info_df != 0][listing_info_df.sqft > 700][listing_info_df.sqft < 2000].plot.bar(x="bedRoomNumber", y="rent", figsize = (15,15))
# Out:
# <ipython-input-177-9842d1e37cb5>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   listing_info_df[listing_info_df != 0][listing_info_df.sqft > 700][listing_info_df.sqft < 2000].plot.bar(x="bedRoomNumber", y="rent", figsize = (15,15))

# %%
print("The row associated with the max value display above")
print(listing_info_df[listing_info_df.sqft == listing_info_df.sqft.max()])
# Out:
# The row associated with the max value display above
#        Unnamed: 0                   propertyName  bedRoomType  bedRoomNumber  \
# 10018       10018  5 bedroom in Seattle WA 98125  Traditional              5
#
#        baths  rent    sqft  availability  deposit unit  leaseLength name  new  \
# 10018    5.0  9800  4380.0             1        0  NaN            0  NaN  NaN
#
#       applyNow
# 10018      NaN

# %%
print("The row associated with the min value display above")
print(listing_info_df[listing_info_df.sqft != 0].min())
# Out:
# The row associated with the min value display above
# Unnamed: 0                                   0
# propertyName     0 bedroom in Seattle WA 98112
# bedRoomType                             Studio
# bedRoomNumber                                1
# baths                                        0
# rent                                         0
# sqft                                        90
# availability                                 0
# deposit                                      0
# leaseLength                                  0
# dtype: object

# %% [markdown]
# ## Create graphs for the listing info dataframe

# %%
listing_info_df[listing_info_df.sqft !=0][listing_info_df.rent != 0].plot(x='rent', y='sqft', kind='scatter', title="Rent vs sqft", figsize=(15,30))
# Out:
# <ipython-input-115-594503d6dacf>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   listing_info_df[listing_info_df.sqft !=0][listing_info_df.rent != 0].plot(x='rent', y='sqft', kind='scatter', title="Rent vs sqft", figsize=(15,30))

# %%
listing_info_df[listing_info_df.sqft != 0].plot(x='bedRoomNumber', y='sqft', kind='scatter', title="bedRoomNumber vs sqft", figsize=(15,10))

# %%
listing_info_df[listing_info_df.rent != 0].plot(x='bedRoomNumber', y='rent', kind='scatter', title="bedRoomNumber vs rent", figsize=(15,10))

# %%
listing_info_df[listing_info_df.sqft !=0][listing_info_df.rent != 0].plot(x='baths', y='sqft', kind='scatter', title="bath vs sqft", figsize=(15,10))
# Out:
# <ipython-input-122-8a4a2ef0eba4>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   listing_info_df[listing_info_df.sqft !=0][listing_info_df.rent != 0].plot(x='baths', y='sqft', kind='scatter', title="bath vs sqft", figsize=(15,10))

# %%
listing_info_df[listing_info_df.sqft !=0][listing_info_df.rent != 0].plot(kind='box', figsize=(15,20))
# Out:
# <ipython-input-90-7b8a0cc9ccb0>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   listing_info_df[listing_info_df.sqft !=0][listing_info_df.rent != 0].plot(kind='box', figsize=(15,20))

# %%
listing_info_df.hist(column="bedRoomNumber", bins=100, figsize=(15,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000027D9680B820>]],
#       dtype=object)

# %%
listing_info_df.hist(column="baths", bins=100, figsize=(15,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000027D969F4130>]],
#       dtype=object)

# %%
listing_info_df[listing_info_df.sqft !=0].hist(column="sqft", bins=200, figsize=(15,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000027D963E55B0>]],
#       dtype=object)

# %%
listing_info_df[listing_info_df.rent != 0].hist(column="rent", bins=200, figsize=(15,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000027DD2C1FD30>]],
#       dtype=object)
